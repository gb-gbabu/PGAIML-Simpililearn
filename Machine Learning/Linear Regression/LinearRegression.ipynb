# %% [raw]
# Problem Statement: A real estate company wants to build homes at different locations in Boston.
#
# They have data for historical prices but haven’t decided the actual prices yet. They want to price it so that it is affordable to the general public.
#
# Objective:
# •Import the Boston data from sklearn and read the description using DESCR
# •Analyzethe data and predict the approximate prices for the houses
#
# Access: Click on the Labs tab on the left side panel of the LMS. Copy or note the username and password that are generated. Click on the LaunchLab button. On the page that appears, enter the username and password in the respective fields, and click Login.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import load_boston

# %%
dataset = load_boston()

# %%
dataset.DESCR.split('\n')
# Out:
# ['.. _boston_dataset:',
#  '',
#  'Boston house prices dataset',
#  '---------------------------',
#  '',
#  '**Data Set Characteristics:**  ',
#  '',
#  '    :Number of Instances: 506 ',
#  '',
#  '    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.',
#  '',
#  '    :Attribute Information (in order):',
#  '        - CRIM     per capita crime rate by town',
#  '        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.',
#  '        - INDUS    proportion of non-retail business acres per town',
#  '        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)',
#  '        - NOX      nitric oxides concentration (parts per 10 million)',
#  '        - RM       average number of rooms per dwelling',
#  '        - AGE      proportion of owner-occupied units built prior to 1940',
#  '        - DIS      weighted distances to five Boston employment centres',
# ...

# %%
dataset.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
dataset.target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
dataset['feature_names']
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
# Convert Dataset to DataFrame

df_boston = pd.DataFrame(data = np.c_[dataset['data']],columns = dataset['feature_names'])

# %%
df_boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
df_boston['MDEV'] = dataset.target

# %%
df_boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MDEV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
df_boston.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MDEV       0
# dtype: int64

# %%
for column in df_boston:
    df_boston.plot(kind = 'scatter', x = column, y = 'MDEV', figsize=(18,6) )

# %%
correlation_matrix = df_boston.corr().round(2)
#annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
for column in df_boston:
    plt.figure()
    sns.boxplot(x=df_boston[column])

# %%
#features = pd.DataFrame(np.c_[df_boston['LSTAT'], df_boston['RM']], columns = ['LSTAT','RM'])
features = df_boston[['LSTAT','RM']]
target = df_boston['MDEV']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(features, target, train_size=0.8, random_state=5)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404, 2)
# (102, 2)
# (404,)
# (102,)

# %%
from sklearn.linear_model import LinearRegression
my_model = LinearRegression()

# %%
my_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(my_model.intercept_)
print(my_model.coef_)
print(features.columns.values.tolist())
list(zip(features.columns,my_model.coef_))
# Out:
# 2.7362403426066138
# [-0.71722954  4.58938833]
# ['LSTAT', 'RM']
# [('LSTAT', -0.7172295427415406), ('RM', 4.58938832844234)]

# %%
from sklearn.metrics import r2_score
# model evaluation for training set
y_train_predict = my_model.predict(X_train)
rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

# model evaluation for testing set
y_test_predict = my_model.predict(X_test)
rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 5.6371293350711955
# R2 score is 0.6300745149331701
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 5.137400784702911
# R2 score is 0.6628996975186953

# %%
#X_new = pd.DataFrame({'RM':[df_boston['RM'].min(),df_boston['RM'].max()],'LSTAT':[df_boston['LSTAT'].min(),df_boston['LSTAT'].max()]})
#X_new

# %%
#predections = my_model.predict(X_new)

# %%
import statsmodels.formula.api as smf

# %%
model = smf.ols(formula = 'MDEV ~  RM + LSTAT ', data = df_boston).fit()
model.pvalues
# Out:
# Intercept    6.687649e-01
# RM           3.472258e-27
# LSTAT        6.669365e-41
# dtype: float64

# %%
model.pvalues.loc['RM'] < 0.05
# Out:
# True

# %%
predictions_train = my_model.predict(X_train)

# %%
from sklearn.metrics import mean_squared_error

# %%
print(X_train.columns.values.tolist())
# Out:
# ['LSTAT', 'RM']

# %%
list(zip(X_train.columns,my_model.coef_))
# Out:
# [('LSTAT', -0.7172295427415406), ('RM', 4.58938832844234)]

# %%
mean_squared_error(predictions_train,y_train)
# Out:
# 31.777227140320214

# %%
predictions_test = my_model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,predictions_test)
# Out:
# 26.392886822666078

# %%
X_new = pd.DataFrame({'CRIM':[df_boston['CRIM'].min(),df_boston['CRIM'].max()],'ZN':[df_boston['ZN'].min(),df_boston['ZN'].max()],'INDUS':[df_boston['INDUS'].min(),df_boston['INDUS'].max()],'CHAS':[df_boston['CHAS'].min(),df_boston['CHAS'].max()],'NOX':[df_boston['NOX'].min(),df_boston['NOX'].max()],'RM':[df_boston['RM'].min(),df_boston['RM'].max()],'AGE':[df_boston['AGE'].min(),df_boston['AGE'].max()],'DIS':[df_boston['DIS'].min(),df_boston['DIS'].max()],'RAD':[df_boston['RAD'].min(),df_boston['RAD'].max()],'TAX':[df_boston['TAX'].min(),df_boston['TAX'].max()],'PTRATIO':[df_boston['PTRATIO'].min(),df_boston['PTRATIO'].max()],'B':[df_boston['B'].min(),df_boston['B'].max()],'LSTAT':[df_boston['LSTAT'].min(),df_boston['LSTAT'].max()]})
X_new
# Out:
#        CRIM     ZN  INDUS  CHAS    NOX     RM    AGE      DIS   RAD    TAX  \
# 0   0.00632    0.0   0.46   0.0  0.385  3.561    2.9   1.1296   1.0  187.0
# 1  88.97620  100.0  27.74   1.0  0.871  8.780  100.0  12.1265  24.0  711.0
#
#    PTRATIO       B  LSTAT
# 0     12.6    0.32   1.73
# 1     22.0  396.90  37.97

# %%
predections = my_model.predict(X_new)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-64db36b91200> in <module>
# ----> 1 predections = my_model.predict(X_new)
#
# ~\Software\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Software\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     217
#     218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
# --> 219         return safe_sparse_dot(X, self.coef_.T,
#     220                                dense_output=True) + self.intercept_
#     221
#
# ~\Software\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
# ...

# %%
import statsmodels.formula.api as smf

# %%
model = smf.ols(formula = ' MDEV ~ CRIM + ZN + INDUS + CHAS + NOX + RM + AGE + DIS + RAD + TAX + PTRATIO +B + LSTAT ', data = df_boston).fit()
model.pvalues

# %%
model.pvalues.loc['RM'] < 0.05

# %%
predictions_test = my_model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(predictions_test,y_test)
